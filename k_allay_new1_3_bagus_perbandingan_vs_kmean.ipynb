# %% [markdown]
# <a href="https://colab.research.google.com/github/elangbijak4/algoritma-dinda-new/blob/main/k_allay_new1_3_bagus_perbandingan_vs_kmean.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from collections import defaultdict
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# Fungsi untuk menghitung benefit dengan konsep fuzzy
def fuzzy_benefit_function(country, main):
    distance = np.linalg.norm(country['position'] - main['position'])
    power_diff = abs(country['power'] - main['power'])

    # Fuzzy logic: higher benefit for closer distance and smaller power_diff
    benefit = (
        np.exp(-distance) * 0.6 +  # Closer countries get higher weight (60%)
        np.exp(-power_diff) * 0.4  # Smaller power differences get lower weight (40%)
    )
    return benefit, distance, power_diff

# Fungsi Dynamic Fuzzy Clustering
def dynamic_threshold_clustering(countries, main_countries, initial_threshold):
    clusters = defaultdict(list)
    reasons = defaultdict(list)
    threshold = initial_threshold
    unassigned_countries = set(country['id'] for country in countries)

    while unassigned_countries:
        for country in countries:
            if country['id'] not in unassigned_countries:
                continue

            best_main = None
            best_benefit = 0
            best_distance = None
            best_power_diff = None

            for main in main_countries:
                benefit, distance, power_diff = fuzzy_benefit_function(country, main)

                # Fuzzy-based threshold comparison
                if benefit > best_benefit and benefit > threshold:
                    best_main = main
                    best_benefit = benefit
                    best_distance = distance
                    best_power_diff = power_diff

            if best_main is not None:
                clusters[best_main['id']].append(country)
                reasons[best_main['id']].append({
                    'country_id': country['id'],
                    'benefit': best_benefit,
                    'distance': best_distance,
                    'power_diff': best_power_diff
                })
                unassigned_countries.remove(country['id'])

        # Dinamis: Turunkan threshold jika masih ada negara yang belum masuk klaster
        if unassigned_countries:
            threshold *= 0.9  # Turunkan threshold 10% setiap iterasi

    return clusters, reasons

# Fungsi K-means Clustering
def kmeans_clustering(countries, n_clusters):
    positions = np.array([country['position'] for country in countries])
    kmeans = KMeans(n_clusters=n_clusters, random_state=42)
    kmeans_labels = kmeans.fit_predict(positions)

    clusters = defaultdict(list)
    for idx, label in enumerate(kmeans_labels):
        clusters[label].append(countries[idx])

    return clusters

# Data contoh
np.random.seed(42)
countries = [
    {'id': i, 'position': np.random.rand(2) * 100, 'power': np.random.rand() * 100}
    for i in range(50)
]
main_countries = [
    {'id': i, 'position': np.random.rand(2) * 100, 'power': np.random.rand() * 100}
    for i in range(5)
]

# Threshold awal
initial_threshold = 0.5

# Jalankan Dynamic Fuzzy Clustering
clusters_dynamic, reasons_dynamic = dynamic_threshold_clustering(countries, main_countries, initial_threshold)

# Jalankan K-means Clustering
clusters_kmeans = kmeans_clustering(countries, n_clusters=len(main_countries))

# Cetak hasil Dynamic Fuzzy Clustering
print("\nDynamic Fuzzy Clustering Results:")
for main_id, cluster in clusters_dynamic.items():
    print(f"\nCluster for Main Country {main_id}:")
    for reason in reasons_dynamic[main_id]:
        print(f"  Country {reason['country_id']} -> Benefit: {reason['benefit']:.4f}, Distance: {reason['distance']:.2f}, Power Diff: {reason['power_diff']:.2f}")

# Cetak hasil K-means Clustering
print("\nK-Means Clustering Results:")
for cluster_id, cluster in clusters_kmeans.items():
    print(f"\nCluster {cluster_id}:")
    for country in cluster:
        print(f"  Country {country['id']} -> Position: {country['position']}, Power: {country['power']:.2f}")
# Out:
# Dynamic Fuzzy Clustering Results:
#
# Cluster for Main Country 4:
#   Country 18 -> Benefit: 0.3342, Distance: 38.77, Power Diff: 0.18
#   Country 22 -> Benefit: 0.0829, Distance: 56.00, Power Diff: 1.57
#   Country 25 -> Benefit: 0.0788, Distance: 25.41, Power Diff: 1.62
#   Country 10 -> Benefit: 0.0321, Distance: 36.62, Power Diff: 2.52
#   Country 27 -> Benefit: 0.0276, Distance: 20.51, Power Diff: 2.67
#   Country 9 -> Benefit: 0.0050, Distance: 13.21, Power Diff: 4.38
#   Country 32 -> Benefit: 0.0006, Distance: 15.49, Power Diff: 6.49
#   Country 42 -> Benefit: 0.0001, Distance: 37.37, Power Diff: 8.33
#
# Cluster for Main Country 3:
#   Country 33 -> Benefit: 0.2653, Distance: 70.56, Power Diff: 0.41
#   Country 6 -> Benefit: 0.0517, Distance: 30.60, Power Diff: 2.05
#   Country 48 -> Benefit: 0.0412, Distance: 55.32, Power Diff: 2.27
#   Country 2 -> Benefit: 0.0177, Distance: 83.51, Power Diff: 3.12
#   Country 12 -> Benefit: 0.0022, Distance: 50.24, Power Diff: 5.19
#   Country 45 -> Benefit: 0.0003, Distance: 43.22, Power Diff: 7.07
#   Country 24 -> Benefit: 0.0002, Distance: 85.01, Power Diff: 7.46
#   Country 15 -> Benefit: 0.0001, Distance: 8.64, Power Diff: 11.22
#   Country 21 -> Benefit: 0.0001, Distance: 38.15, Power Diff: 8.96
#   Country 39 -> Benefit: 0.0000, Distance: 75.42, Power Diff: 9.30
#   Country 28 -> Benefit: 0.0000, Distance: 41.94, Power Diff: 9.73
#   Country 0 -> Benefit: 0.0000, Distance: 68.18, Power Diff: 9.97
#   Country 5 -> Benefit: 0.0000, Distance: 54.85, Power Diff: 10.75
#   Country 35 -> Benefit: 0.0000, Distance: 48.08, Power Diff: 12.32
#   Country 30 -> Benefit: 0.0000, Distance: 69.98, Power Diff: 12.85
#   Country 13 -> Benefit: 0.0000, Distance: 37.86, Power Diff: 13.71
#   Country 37 -> Benefit: 0.0000, Distance: 79.83, Power Diff: 17.58
#   Country 11 -> Benefit: 0.0000, Distance: 63.73, Power Diff: 17.61
#   Country 20 -> Benefit: 0.0000, Distance: 35.30, Power Diff: 19.64
#   Country 26 -> Benefit: 0.0000, Distance: 44.74, Power Diff: 23.08
#   Country 16 -> Benefit: 0.0000, Distance: 25.77, Power Diff: 33.73
#   Country 34 -> Benefit: 0.0000, Distance: 43.72, Power Diff: 27.53
#   Country 44 -> Benefit: 0.0000, Distance: 60.91, Power Diff: 31.06
#
# Cluster for Main Country 0:
#   Country 1 -> Benefit: 0.1318, Distance: 32.07, Power Diff: 1.11
#   Country 4 -> Benefit: 0.0101, Distance: 8.06, Power Diff: 3.69
#   Country 3 -> Benefit: 0.0000, Distance: 29.67, Power Diff: 82.50
#
# Cluster for Main Country 2:
#   Country 43 -> Benefit: 0.0846, Distance: 38.02, Power Diff: 1.55
#   Country 8 -> Benefit: 0.0090, Distance: 21.73, Power Diff: 3.80
#   Country 23 -> Benefit: 0.0082, Distance: 31.49, Power Diff: 3.89
#   Country 31 -> Benefit: 0.0000, Distance: 11.13, Power Diff: 25.62
#   Country 38 -> Benefit: 0.0000, Distance: 11.65, Power Diff: 56.60
#   Country 29 -> Benefit: 0.0000, Distance: 13.03, Power Diff: 23.46
#   Country 17 -> Benefit: 0.0000, Distance: 20.55, Power Diff: 65.72
#
# Cluster for Main Country 1:
#   Country 14 -> Benefit: 0.0751, Distance: 46.14, Power Diff: 1.67
#   Country 49 -> Benefit: 0.0103, Distance: 93.43, Power Diff: 3.66
#   Country 36 -> Benefit: 0.0034, Distance: 94.53, Power Diff: 4.77
#   Country 47 -> Benefit: 0.0011, Distance: 54.32, Power Diff: 5.88
#   Country 40 -> Benefit: 0.0002, Distance: 33.04, Power Diff: 7.59
#   Country 19 -> Benefit: 0.0001, Distance: 98.51, Power Diff: 8.33
#   Country 46 -> Benefit: 0.0000, Distance: 12.66, Power Diff: 72.04
#   Country 7 -> Benefit: 0.0000, Distance: 77.68, Power Diff: 12.43
#   Country 41 -> Benefit: 0.0000, Distance: 84.74, Power Diff: 18.51
#
# K-Means Clustering Results:
#
# Cluster 2:
#   Country 0 -> Position: [37.45401188 95.07143064], Power: 73.20
#   Country 2 -> Position: [ 5.80836122 86.61761458], Power: 60.11
#   Country 14 -> Position: [ 3.43885211 90.93204021], Power: 25.88
#   Country 22 -> Position: [14.0924225  80.21969808], Power: 7.46
#   Country 24 -> Position: [ 0.55221171 81.54614285], Power: 70.69
#   Country 30 -> Position: [11.95942459 71.32447872], Power: 76.08
#   Country 37 -> Position: [16.12212873 92.96976523], Power: 80.81
#   Country 39 -> Position: [18.65700589 89.25589985], Power: 53.93
#   Country 46 -> Position: [36.36296024 97.17820827], Power: 96.24
#
# Cluster 4:
#   Country 1 -> Position: [59.86584842 15.60186404], Power: 15.60
#   Country 3 -> Position: [70.80725778  2.05844943], Power: 96.99
#   Country 4 -> Position: [83.24426408 21.23391107], Power: 18.18
#   Country 10 -> Position: [60.75448519 17.05241237], Power: 6.51
#   Country 13 -> Position: [44.01524937 12.20382348], Power: 49.52
#   Country 15 -> Position: [66.25222844 31.17110761], Power: 52.01
#   Country 16 -> Position: [54.67102793 18.48544555], Power: 96.96
#   Country 27 -> Position: [62.32981268 33.08980249], Power: 6.36
#   Country 49 -> Position: [50.26790232  5.14787512], Power: 27.86
#
# Cluster 1:
#   Country 5 -> Position: [18.34045099 30.4242243 ], Power: 52.48
#   Country 7 -> Position: [13.94938607 29.21446485], Power: 36.64
#   Country 12 -> Position: [30.46137692  9.7672114 ], Power: 68.42
#   Country 19 -> Position: [19.59828624  4.52272889], Power: 32.53
#   Country 26 -> Position: [35.84657285 11.58690595], Power: 86.31
#   Country 33 -> Position: [10.7891427   3.14291857], Power: 63.64
#   Country 36 -> Position: [22.87981655  7.69799098], Power: 28.98
#   Country 41 -> Position: [11.00519245 22.79351625], Power: 42.71
#   Country 44 -> Position: [11.98653673 33.76151714], Power: 94.29
#   Country 48 -> Position: [28.48404944  3.68869474], Power: 60.96
#
# Cluster 3:
#   Country 6 -> Position: [43.19450186 29.12291402], Power: 61.19
#   Country 9 -> Position: [51.42344384 59.24145689], Power: 4.65
#   Country 20 -> Position: [38.86772897 27.13490318], Power: 82.87
#   Country 21 -> Position: [35.67533267 28.09345097], Power: 54.27
#   Country 28 -> Position: [31.09823217 32.5183322 ], Power: 72.96
#   Country 32 -> Position: [52.27328294 42.75410184], Power: 2.54
#   Country 34 -> Position: [31.43559811 50.85706912], Power: 90.76
#   Country 35 -> Position: [24.92922291 41.0382923 ], Power: 75.56
#   Country 43 -> Position: [51.07473026 41.74110031], Power: 22.21
#   Country 45 -> Position: [32.3202932  51.87906217], Power: 70.30
#   Country 47 -> Position: [25.17822958 49.72485059], Power: 30.09
#
# Cluster 0:
#   Country 8 -> Position: [45.60699842 78.51759614], Power: 19.97
#   Country 11 -> Position: [94.88855373 96.56320331], Power: 80.84
#   Country 17 -> Position: [77.51328234 93.94989416], Power: 89.48
#   Country 18 -> Position: [59.78999788 92.1874235 ], Power: 8.85
#   Country 23 -> Position: [98.68869366 77.22447693], Power: 19.87
#   Country 25 -> Position: [72.9007168  77.12703467], Power: 7.40
#   Country 29 -> Position: [63.75574714 88.72127426], Power: 47.22
#   Country 31 -> Position: [56.12771976 77.096718  ], Power: 49.38
#   Country 38 -> Position: [63.34037565 87.14605902], Power: 80.37
#   Country 40 -> Position: [80.74401552 89.60912999], Power: 31.80
#   Country 42 -> Position: [81.80147659 86.07305833], Power: 0.70
